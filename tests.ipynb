# %% [markdown]
# > 01. \\ 2 | C05 ~ 0.4425
#
# > 02. \\ 2 | C05 ~ 0.4400
#
# > 03. \\ 2 | C05 ~ 0.446
# > en supprimant num_orders + answers_days + mean_items + total_items / en remplaçant montant à 0.99 (mais pas le reste)
# >> PAS fan du découpage
#
# > 04. \\ 2 | C05 ~ 0.4400/0.4450
#
# > ~~05. / 2 | C05 ~ 0.3875~~
#
# > ~~06. \\ 2 | C07 ~ 0.3750~~
#
# > ~~07. \\ 2 | C06 ~ 0.3350~~
#
# > ~~08. \\ 2 | C04 ~ 0.3225~~
#
# > ~~09. \\ 2 | C05 ~ 0.3750~~
#
# > 10. \\ 2 | C05 ~ 0.4275 ~ modèle avec lat/long
#
# > ~~11. xx~~
#
# > ~~12. xx~~
#
# > 13. / 1 | C05 ~ 0.402
# > en remplacant montant et answers_days à 0.99 (mais pas le reste)
# >> Découpage comme le 03, mais avec un groupe ou les clients ont mis longtemps à répondre au mail...
#
# > 14. / 1 | C04 ~ 0.4350
#
# > 15. / 1 | C04 ~ 0.4125
#
# > ~~16. xx~~
#
# > 17. / 1 | C04 ~ 0.434
# > en remplacant montant à 0.99 (mais pas le reste)
# >> PAS fan du découpage / on a en gros la même chose qu'en 03
#
# > ~~18. xx~~
#
# > 19. \\ 2 | C04 ~ 0.4350
#
# > 20. \\ 2 | C04 ~ 0.4375
#
# > ~~21. xx~~
#
# > ~~22. xx~~
#
# > ~~23. xx~~
#
# > ~~24. xx~~
#
# > ~~25. xx~~

# %% [markdown]
# # Silhouettes scores

# %% [markdown]
# ## 01 - 20K samples / en remplacant montant à 0.99 (mais pas le reste) / avec avg_num_comments

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 02 - 20K samples / en remplacant montant à 0.99 (mais pas le reste) / avec avg_num_comments + num_orders

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 03 - 20K samples / en supprimant num_orders + answers_days + mean_items + total_items / en remplaçant montant à 0.99 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 04 - 20K samples / en supprimant num_orders + answers_days + mean_items / en remplaçant montant à 0.99 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 05 - 20K samples / en supprimant num_orders + answers_days + mean_items + total_items / en remplaçant montant par M_data

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 06 - 20K samples / en supprimant num_orders + answers_days + mean_items + total_items / en remplaçant montant à 0.90 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 07 - 20K samples / en supprimant num_orders + answers_days + mean_items + total_items / en ajoutant la lat et long / en remplaçant montant à 0.90 (mais pas le reste) / en reduisant les lat/long au brezil

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 08 - 20K samples / en supprimant num_orders + answers_days + mean_items + total_items / en ajoutant la lat et long / en remplaçant montant à 0.80 (mais pas le reste) / en reduisant les lat/long au brezil

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 09 - 20K samples / en supprimant num_orders + answers_days + mean_items + total_items / en ajoutant la lat et long / en remplaçant montant à 0.99 (mais pas le reste) / en reduisant les lat/long au brezil

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10 - 20K samples / en supprimant num_orders + answers_days + mean_items + total_items / en ajoutant la lat et long / en remplaçant montant à 0.99 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 11 - 20K samples / en remplacant montant par un log10 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 12 - 20K samples / en remplacant montant par un log2 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 13 - 20K samples / en remplacant montant et answers_days à 0.99 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 14 - 20K samples / avec panier moyen / sans montant & en remplacant panier_moyen à 0.99 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 15 - 20K samples / avec panier moyen & en remplacant montant/panier_moyen à 0.99 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 16 - 20K samples / avec panier moyen & M_score & en remplacant montant/panier_moyen à 0.99 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 17 - 20K samples / en remplacant montant à 0.99 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 18 - 20K samples / en remplacant montant à 0.995 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 19 - 20K samples / en remplacant montant à 0.999 (mais pas le reste)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 20 - 20K samples / sans les outliers montant (le reste oui) à 0.999

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 21 - 20K samples / sans les outliers montant (le reste oui) à 0.995

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 22 - 20K samples / sans les outliers montant (le reste oui) à 0.99

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 23 - 20K samples / sans les outliers à 0.999

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 24 - 20K samples / en remplaçant les outliers (0.99)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [raw]
# ## 25 - 20K samples / en remplaçant les outliers (0.999)

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 20), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 26 - 18K samples / recence + montant + review_score + total_items / sans correction outliers

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 27 - 18K samples / recence + montant + review_score + total_items + num_orders / sans correction outliers

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 28 - 18K samples / recence + montant + review_score + total_items + num_orders / montant remplacé à 0.999

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 29 - 18K samples / recence + montant + review_score + mean_items + total_items + num_orders / montants <0 supprimés

# %%
methods = ['distortion', 'silhouette'] #, 'calinski_harabasz']
kmeans = KMeans(random_state=random_seed)

fig = plt.figure(figsize=(15, 5))
for i, m in enumerate(methods):
    ax = plt.subplot(1, 3, i+1)
    visualizer = KElbowVisualizer(kmeans, k=(3, 15), metric=m, timings=False)
    visualizer.fit(X_training)
    plt.title(f"{m.title()} scores for KMeans Clustering")
    ax.set_ylabel(f'{m} score')
    ax.set_xlabel('k')
    #visualizer.show();

plt.tight_layout()
plt.show()

# %% [markdown]
# # ARI

# %% [markdown]
# ## 01 - 18K samples / 9 clusters / base / no overfit action

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(rand_scores)
plt.ylim([0,1.1])
plt.xlabel("Glissement des données en mois par rapport au jeu de données d'origine")
plt.ylabel("Adjusted Rand Index")
plt.show()

# %% [markdown]
# ## 02 - 18K samples / 8 clusters / base / no overfit action

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(rand_scores)
plt.ylim([0,1.1])
plt.xlabel("Glissement des données en mois par rapport au jeu de données d'origine")
plt.ylabel("Adjusted Rand Index")
plt.show()

# %% [markdown]
# ## 03 - 18K samples / 4 clusters / base / no overfit action

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(rand_scores)
plt.ylim([0,1.1])
plt.xlabel("Glissement des données en mois par rapport au jeu de données d'origine")
plt.ylabel("Adjusted Rand Index")
plt.show()

# %% [markdown]
# ## 04 - 18K samples / 5 clusters / recence + montant + review_score / no overfit action

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(rand_scores)
plt.ylim([0,1.1])
plt.xlabel("Glissement des données en mois par rapport au jeu de données d'origine")
plt.ylabel("Adjusted Rand Index")
plt.show()

# %% [markdown]
# ## 05 - 18K samples / 5 clusters / recence + montant + review_score + total_items / no overfit action

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(rand_scores)
plt.ylim([0,1.1])
plt.xlabel("Glissement des données en mois par rapport au jeu de données d'origine")
plt.ylabel("Adjusted Rand Index")
plt.show()

# %% [markdown]
# ## 06 - 18K samples / 8 clusters / recence + montant + review_score + total_items / no overfit action

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(rand_scores)
plt.ylim([0,1.1])
plt.xlabel("Glissement des données en mois par rapport au jeu de données d'origine")
plt.ylabel("Adjusted Rand Index")
plt.show()

# %% [markdown]
# ## 07 - 18K samples / 4 clusters / recence + montant + review_score + total_items / no overfit action

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(rand_scores)
plt.ylim([0,1.1])
plt.xlabel("Glissement des données en mois par rapport au jeu de données d'origine")
plt.ylabel("Adjusted Rand Index")
plt.show()

# %% [markdown]
# ## 08 - 18K samples / 4 clusters / recence + montant + review_score + total_items / montant remplacé à 0.999

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(rand_scores)
plt.ylim([0,1.1])
plt.xlabel("Glissement des données en mois par rapport au jeu de données d'origine")
plt.ylabel("Adjusted Rand Index")
plt.show()

# %% [markdown]
# ## 09 - 18K samples / 8 clusters / recence + montant + review_score + total_items / montant remplacé à 0.999

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(rand_scores)
plt.ylim([0,1.1])
plt.xlabel("Glissement des données en mois par rapport au jeu de données d'origine")
plt.ylabel("Adjusted Rand Index")
plt.show()

# %% [markdown]
# ## 10 - 18K samples / 9 clusters / recence + montant + review_score + answer_days + mean_items + total_items / tout est remplacé à 0.995

# %%
fig = plt.figure(figsize=(15, 5))
plt.plot(rand_scores)
plt.ylim([0,1.1])
plt.xlabel("Glissement des données en mois par rapport au jeu de données d'origine")
plt.ylabel("Adjusted Rand Index")
plt.show()
